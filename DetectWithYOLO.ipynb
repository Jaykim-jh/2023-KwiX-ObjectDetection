# %%
import yaml
from ultralytics import YOLO

# %%
model = YOLO('yolov5s.pt')

model.train(data='C:\Download/Visdrone.yaml', epochs=20, patience=30, batch=32, imgsz=640)

results = model.predict(source='C:\Download/VisDrone2019-DET-test-challenge/images/', save=True)
# Out:
# PRO TIP  Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics YOLOv8.0.121  Python-3.8.16 torch-2.0.1+cpu CPU
# ...
